# %%
pip install pydrive
# Out:
# Collecting pydrive
#   Downloading PyDrive-1.3.1.tar.gz (987 kB)
#      ---------------------------------------- 0.0/987.4 kB ? eta -:--:--
#      - ----------------------------------- 30.7/987.4 kB 445.2 kB/s eta 0:00:03
#      --------- ---------------------------- 235.5/987.4 kB 2.4 MB/s eta 0:00:01
#      -------------------------- ----------- 696.3/987.4 kB 4.9 MB/s eta 0:00:01
#      -------------------------------------- 987.4/987.4 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting google-api-python-client>=1.2 (from pydrive)
#   Downloading google_api_python_client-2.154.0-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting oauth2client>=4.0.0 (from pydrive)
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: PyYAML>=3.0 in c:\users\scrum\appdata\local\programs\python\python312\lib\site-packages (from pydrive) (6.0.1)
# Collecting httplib2<1.dev0,>=0.19.0 (from google-api-python-client>=1.2->pydrive)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 (from google-api-python-client>=1.2->pydrive)
#   Downloading google_auth-2.36.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client>=1.2->pydrive)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client>=1.2->pydrive)
#   Downloading google_api_core-2.23.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client>=1.2->pydrive)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting pyasn1>=0.1.7 (from oauth2client>=4.0.0->pydrive)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting pyasn1-modules>=0.0.5 (from oauth2client>=4.0.0->pydrive)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa>=3.1.4 (from oauth2client>=4.0.0->pydrive)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: six>=1.6.1 in c:\users\scrum\appdata\local\programs\python\python312\lib\site-packages (from oauth2client>=4.0.0->pydrive) (1.16.0)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive)
#   Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in c:\users\scrum\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (4.25.4)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive)
#   Downloading proto_plus-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\scrum\appdata\local\programs\python\python312\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (2.32.3)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client>=1.2->pydrive)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\scrum\appdata\local\programs\python\python312\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client>=1.2->pydrive) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\scrum\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\scrum\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\scrum\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\scrum\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.2->pydrive) (2024.6.2)
# Downloading google_api_python_client-2.154.0-py2.py3-none-any.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    - -------------------------------------- 0.4/12.6 MB 7.4 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/12.6 MB 8.7 MB/s eta 0:00:02
#    --- ------------------------------------ 1.2/12.6 MB 8.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/12.6 MB 8.5 MB/s eta 0:00:02
#    ------ --------------------------------- 2.1/12.6 MB 8.8 MB/s eta 0:00:02
#    ------- -------------------------------- 2.5/12.6 MB 9.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.9/12.6 MB 8.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.3/12.6 MB 8.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.8/12.6 MB 8.9 MB/s eta 0:00:01
#    ------------- -------------------------- 4.3/12.6 MB 9.4 MB/s eta 0:00:01
#    -------------- ------------------------- 4.7/12.6 MB 9.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.6 MB 9.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.6/12.6 MB 9.5 MB/s eta 0:00:01
#    ------------------- -------------------- 6.1/12.6 MB 9.5 MB/s eta 0:00:01
#    -------------------- ------------------- 6.5/12.6 MB 9.4 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.6 MB 9.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.1/12.6 MB 9.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.4/12.6 MB 8.9 MB/s eta 0:00:01
#    ------------------------ --------------- 7.7/12.6 MB 8.8 MB/s eta 0:00:01
#    ------------------------- -------------- 8.2/12.6 MB 8.9 MB/s eta 0:00:01
#    --------------------------- ------------ 8.6/12.6 MB 8.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.9/12.6 MB 8.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.0/12.6 MB 8.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.6 MB 8.4 MB/s eta 0:00:01
#    ------------------------------- -------- 9.8/12.6 MB 8.5 MB/s eta 0:00:01
#    -------------------------------- ------- 10.3/12.6 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.6 MB 8.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.1/12.6 MB 8.6 MB/s eta 0:00:01
#    ------------------------------------ --- 11.6/12.6 MB 8.6 MB/s eta 0:00:01
#    -------------------------------------- - 12.0/12.6 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  12.4/12.6 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 8.4 MB/s eta 0:00:00
# Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#    ---------------------------------------- 0.0/98.2 kB ? eta -:--:--
#    ---------------------------------------- 98.2/98.2 kB 5.5 MB/s eta 0:00:00
# Downloading google_api_core-2.23.0-py3-none-any.whl (156 kB)
#    ---------------------------------------- 0.0/156.6 kB ? eta -:--:--
#    ---------------------------------------- 156.6/156.6 kB 9.1 MB/s eta 0:00:00
# Downloading google_auth-2.36.0-py2.py3-none-any.whl (209 kB)
#    ---------------------------------------- 0.0/209.5 kB ? eta -:--:--
#    ---------------------------------------- 209.5/209.5 kB 6.2 MB/s eta 0:00:00
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#    ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#    ---------------------------------------- 96.9/96.9 kB 5.4 MB/s eta 0:00:00
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.1 kB ? eta -:--:--
#    ---------------------------------------- 83.1/83.1 kB ? eta 0:00:00
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#    ---------------------------------------- 0.0/181.5 kB ? eta -:--:--
#    ---------------------------------------- 181.5/181.5 kB 5.5 MB/s eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
#    ---------------------------------------- 0.0/221.7 kB ? eta -:--:--
#    ---------------------------------------- 221.7/221.7 kB 6.6 MB/s eta 0:00:00
# Downloading proto_plus-1.25.0-py3-none-any.whl (50 kB)
#    ---------------------------------------- 0.0/50.1 kB ? eta -:--:--
#    ---------------------------------------- 50.1/50.1 kB 2.7 MB/s eta 0:00:00
# Building wheels for collected packages: pydrive
#   Building wheel for pydrive (setup.py): started
#   Building wheel for pydrive (setup.py): finished with status 'done'
#   Created wheel for pydrive: filename=PyDrive-1.3.1-py3-none-any.whl size=27462 sha256=dd35a1d47c5ff9d539a5cff2c1db601fff6341e6e7a2127d81653e2431259b5e
#   Stored in directory: c:\users\scrum\appdata\local\pip\cache\wheels\6c\10\da\a5b513f5b3916fc391c20ee7b4633e5cf3396d570cdd74970f
# Successfully built pydrive
# Installing collected packages: uritemplate, pyasn1, proto-plus, httplib2, googleapis-common-protos, cachetools, rsa, pyasn1-modules, oauth2client, google-auth, google-auth-httplib2, google-api-core, google-api-python-client, pydrive
# Successfully installed cachetools-5.5.0 google-api-core-2.23.0 google-api-python-client-2.154.0 google-auth-2.36.0 google-auth-httplib2-0.2.0 googleapis-common-protos-1.66.0 httplib2-0.22.0 oauth2client-4.1.3 proto-plus-1.25.0 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydrive-1.3.1 rsa-4.9 uritemplate-4.1.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

# %%
# Google認証
gauth = GoogleAuth()
gauth.LoadCredentialsFile("credentials.json")
if gauth.credentials is None:
    gauth.LocalWebserverAuth()  # 初回認証（ブラウザが開きます）
    gauth.SaveCredentialsFile("credentials.json")
else:
    gauth.Authorize()

drive = GoogleDrive(gauth)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\scrum\AppData\Local\Programs\Python\Python312\Lib\site-packages\oauth2client\clientsecrets.py:121, in _loadfile(filename)
#     120 try:
# --> 121     with open(filename, 'r') as fp:
#     122         obj = json.load(fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'client_secrets.json'
#
# During handling of the above exception, another exception occurred:
#
# InvalidClientSecretsError                 Traceback (most recent call last)
# File c:\Users\scrum\AppData\Local\Programs\Python\Python312\Lib\site-packages\pydrive\auth.py:386, in GoogleAuth.LoadClientConfigFile(self, client_config_file)
#     385 try:
# --> 386   client_type, client_info = clientsecrets.loadfile(client_config_file)
#     387 except clientsecrets.InvalidClientSecretsError as error:
#
# File c:\Users\scrum\AppData\Local\Programs\Python\Python312\Lib\site-packages\oauth2client\clientsecrets.py:165, in loadfile(filename, cache)
#     164 if not cache:
# --> 165     return _loadfile(filename)
#     167 obj = cache.get(filename, namespace=_SECRET_NAMESPACE)
#
# File c:\Users\scrum\AppData\Local\Programs\Python\Python312\Lib\site-packages\oauth2client\clientsecrets.py:124, in _loadfile(filename)
#     123 except IOError as exc:
# --> 124     raise InvalidClientSecretsError('Error opening file', exc.filename,
#     125                                     exc.strerror, exc.errno)
#     126 return _validate_clientsecrets(obj)
#
# InvalidClientSecretsError: ('Error opening file', 'client_secrets.json', 'No such file or directory', 2)
#
# During handling of the above exception, another exception occurred:
#
# InvalidConfigError                        Traceback (most recent call last)
# Cell In[6], line 5
#       3 gauth.LoadCredentialsFile("credentials.json")
#       4 if gauth.credentials is None:
# ----> 5     gauth.LocalWebserverAuth()  # 初回認証（ブラウザが開きます）
#       6     gauth.SaveCredentialsFile("credentials.json")
#       7 else:
#
# File c:\Users\scrum\AppData\Local\Programs\Python\Python312\Lib\site-packages\pydrive\auth.py:113, in CheckAuth.<locals>._decorated(self, *args, **kwargs)
#     111   self.LoadCredentials()
#     112 if self.flow is None:
# --> 113   self.GetFlow()
#     114 if self.credentials is None:
#     115   code = decoratee(self, *args, **kwargs)
#
# File c:\Users\scrum\AppData\Local\Programs\Python\Python312\Lib\site-packages\pydrive\auth.py:443, in GoogleAuth.GetFlow(self)
#     437 """Gets Flow object from client configuration.
#     438
#     439 :raises: InvalidConfigError
#     440 """
#     441 if not all(config in self.client_config \
#     442            for config in self.CLIENT_CONFIGS_LIST):
# --> 443   self.LoadClientConfig()
#     444 constructor_kwargs = {
#     445     'redirect_uri': self.client_config['redirect_uri'],
#     446     'auth_uri': self.client_config['auth_uri'],
#     447     'token_uri': self.client_config['token_uri'],
#     448 }
#     449 if self.client_config['revoke_uri'] is not None:
#
# File c:\Users\scrum\AppData\Local\Programs\Python\Python312\Lib\site-packages\pydrive\auth.py:366, in GoogleAuth.LoadClientConfig(self, backend)
#     364     raise InvalidConfigError('Please specify client config backend')
#     365 if backend == 'file':
# --> 366   self.LoadClientConfigFile()
#     367 elif backend == 'settings':
#     368   self.LoadClientConfigSettings()
#
# File c:\Users\scrum\AppData\Local\Programs\Python\Python312\Lib\site-packages\pydrive\auth.py:388, in GoogleAuth.LoadClientConfigFile(self, client_config_file)
#     386   client_type, client_info = clientsecrets.loadfile(client_config_file)
#     387 except clientsecrets.InvalidClientSecretsError as error:
# --> 388   raise InvalidConfigError('Invalid client secrets file %s' % error)
#     389 if not client_type in (clientsecrets.TYPE_WEB,
#     390                        clientsecrets.TYPE_INSTALLED):
#     391   raise InvalidConfigError('Unknown client_type of client config file')
#
# InvalidConfigError: Invalid client secrets file ('Error opening file', 'client_secrets.json', 'No such file or directory', 2)

# %%
# フォルダIDを設定
folder_id = 'your_folder_id_here'  # G:\マイドライブ\ペイントソフト実験\被験者データ\01 に対応するフォルダIDを指定

# フォルダ内のファイル一覧を取得
file_list = drive.ListFile({'q': f"'{folder_id}' in parents and trashed=false"}).GetList()

# フォルダやファイルの内容を表示
for file in file_list:
    print(f"Name: {file['title']}, ID: {file['id']}")
