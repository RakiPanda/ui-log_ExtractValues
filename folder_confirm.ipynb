# %% [markdown]
# フォルダ確認

# %%
import os

# ベースフォルダパス（番号部分を除いた固定部分）
base_folder_path = r".\SubjectData"

# フォルダの番号範囲を指定（01, 02, ..., 25）
for i in range(1, 26):  # 必要な番号の範囲を設定（例: 1〜25）
    # フォルダ番号を2桁にする（01, 02, ...）
    folder_number = f"{i:02d}"
    # 完全なフォルダパスを生成
    folder_path = os.path.join(base_folder_path, folder_number, "logs")
    
    print(f"\n確認中: '{folder_path}'")
    if os.path.exists(folder_path):
        print(f"'{folder_path}' 内のファイルとフォルダ:")
        # フォルダ内のファイルやディレクトリをリストアップ
        for item in os.listdir(folder_path):
            item_path = os.path.join(folder_path, item)
            if os.path.isdir(item_path):
                print(f"📁 フォルダ: {item}")
            elif os.path.isfile(item_path):
                print(f"📄 ファイル: {item}")
    else:
        print(f"指定したパス '{folder_path}' は存在しません。")
# Out:
# 確認中: '.\被験者データ\01\logs'
# '.\被験者データ\01\logs' 内のファイルとフォルダ:
# 📄 ファイル: ui-log_土_7-12-2024_15-14-32.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-20-28.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-28-23.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-30-37.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-32-51.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-34-32.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-40-05.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-41-37.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-43-08.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-44-45.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-46-20.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-52-22.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-53-40.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-55-19.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-56-25.txt
# 📄 ファイル: ui-log_土_7-12-2024_15-57-44.txt
#
# 確認中: '.\被験者データ\02\logs'
# '.\被験者データ\02\logs' 内のファイルとフォルダ:
# 📄 ファイル: ui-log_火_10-12-2024_19-03-36.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-08-24.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-14-12_誤って保存.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-18-32.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-20-57_タスク2で間違ってspare01に保存してspare01を開く.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-21-16.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-22-49.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-24-10.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-35-19.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-36-20.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-37-36.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-38-44.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-40-20.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-44-43.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-46-22.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-47-23.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-48-34.txt
# 📄 ファイル: ui-log_火_10-12-2024_19-49-37.txt
#
# 確認中: '.\被験者データ\03\logs'
# '.\被験者データ\03\logs' 内のファイルとフォルダ:
# 📄 ファイル: ui-log_水_11-12-2024_10-02-09.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-06-24.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-10-25.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-12-10.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-13-30.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-14-53.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-17-41.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-19-14.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-20-26.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-21-35.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-22-45.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-25-28.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-26-30.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-27-41.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-28-43.txt
# 📄 ファイル: ui-log_水_11-12-2024_10-29-42.txt
#
# 確認中: '.\被験者データ\04\logs'
# 指定したパス '.\被験者データ\04\logs' は存在しません。
#
# 確認中: '.\被験者データ\05\logs'
# 指定したパス '.\被験者データ\05\logs' は存在しません。
#
# 確認中: '.\被験者データ\06\logs'
# 指定したパス '.\被験者データ\06\logs' は存在しません。
#
# 確認中: '.\被験者データ\07\logs'
# 指定したパス '.\被験者データ\07\logs' は存在しません。
#
# 確認中: '.\被験者データ\08\logs'
# 指定したパス '.\被験者データ\08\logs' は存在しません。
#
# 確認中: '.\被験者データ\09\logs'
# 指定したパス '.\被験者データ\09\logs' は存在しません。
#
# 確認中: '.\被験者データ\10\logs'
# 指定したパス '.\被験者データ\10\logs' は存在しません。
#
# 確認中: '.\被験者データ\11\logs'
# 指定したパス '.\被験者データ\11\logs' は存在しません。
#
# 確認中: '.\被験者データ\12\logs'
# 指定したパス '.\被験者データ\12\logs' は存在しません。
#
# 確認中: '.\被験者データ\13\logs'
# 指定したパス '.\被験者データ\13\logs' は存在しません。
#
# 確認中: '.\被験者データ\14\logs'
# 指定したパス '.\被験者データ\14\logs' は存在しません。
#
# 確認中: '.\被験者データ\15\logs'
# 指定したパス '.\被験者データ\15\logs' は存在しません。
#
# 確認中: '.\被験者データ\16\logs'
# 指定したパス '.\被験者データ\16\logs' は存在しません。
#
# 確認中: '.\被験者データ\17\logs'
# 指定したパス '.\被験者データ\17\logs' は存在しません。
#
# 確認中: '.\被験者データ\18\logs'
# 指定したパス '.\被験者データ\18\logs' は存在しません。
#
# 確認中: '.\被験者データ\19\logs'
# 指定したパス '.\被験者データ\19\logs' は存在しません。
#
# 確認中: '.\被験者データ\20\logs'
# 指定したパス '.\被験者データ\20\logs' は存在しません。
#
# 確認中: '.\被験者データ\21\logs'
# 指定したパス '.\被験者データ\21\logs' は存在しません。
#
# 確認中: '.\被験者データ\22\logs'
# 指定したパス '.\被験者データ\22\logs' は存在しません。
#
# 確認中: '.\被験者データ\23\logs'
# 指定したパス '.\被験者データ\23\logs' は存在しません。
#
# 確認中: '.\被験者データ\24\logs'
# 指定したパス '.\被験者データ\24\logs' は存在しません。
#
# 確認中: '.\被験者データ\25\logs'
# 指定したパス '.\被験者データ\25\logs' は存在しません。
